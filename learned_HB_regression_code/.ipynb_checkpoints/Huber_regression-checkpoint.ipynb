# %%
# %load train_regression
import argparse
import os
import torch
from data.ghg import getGHG
from data.gas import getGas
from data.electric import getElectric
from evaluate import *
from pathlib import Path
import sys
import time
from misc_utils import *
import warnings
from tqdm import tqdm
import numpy as np
from sklearn.datasets import make_regression
from sklearn.linear_model import HuberRegressor, LinearRegression


def make_parser_reg():
    parser = argparse.ArgumentParser()

    def aa(*args, **kwargs):
        parser.add_argument(*args, **kwargs)

    aa("--data", type=str, default="ghg", help="ghg|gas|electric")
   # aa("--dataname", type=str, default="mit", help="eagle|mit|friends")
    aa("--m", type=int, default=10, help="m for S")
    # the row num of S
    # aa("--k", type=int, default=10, help="target: rank k approximation")
    # aa("--mp", type=int, default=10, help="mp for R")
    aa("--iter", type=int, default=8000, help="total iterations")
    # aa("--scale", type=int, default= 100, help="scale") # not a functioning argument, assume 100

    aa("--random", default=False, action='store_true',
       help="don't learn S! Just compute error on random S")

    aa("--size", type=int, default=2000, help="dataset size")
    # aa("--bw", dest='bw', default=False, action='store_true', help="input images to black and white")
    # aa("--dwnsmp", type=int, default=1, help="how much to downsample input images")
    # aa("--dense", type=int, default=-1, help="calculate dense?")
    # aa("--lr_S", type=float, default=1.0, help="learning rate scale?")
    aa("--lr", type=float, default=1e-4, help="learning rate for gradient descent")
    aa("--raw", dest='raw', default=True,
       action='store_true', help="generate raw?")
    aa("--bestonly", dest='bestonly', default=False,
       action='store_true', help="only compute best?")
    aa("--device", type=str, default="cuda:0")

    # aa("--n_sample_rows", type=int, default=-1, help="Train with n_sample_rows rows")
    aa("--k_sparse", type=int, default=1,
       help="number of values in a column of S, sketching mat")
    aa("--num_exp", type=int, default=1,
       help="number of times to rerun the experiment (for avg'ing results)")
    aa("--bs", type=int, default=10, help="batch size")
    aa("--initalg", type=str, default="random",
       help="random|kmeans|lev|gs|lev_cluster|load")
    aa("--load_file", type=str, default="",
       help="if initalg=load, where to get S?")

    aa("--save_fldr", type=str,
       help="folder to save experiment results into; if None, then general folder")  # default: None
    aa("--save_file", type=str, help="append to runtype, if not None")

    aa("--S_init_method", type=str, default="gaussian",
       help="pm1|gaussian|gaussian_pm1")
    # aa("--lev_ridge", dest='lev_ridge', default=False, action='store_true',
    #    help="use ridge regression version with lambda?")
    # aa("--lev_cutoff", type=int, help="how many top k to isolate; must be <=m? if m, then not isolate, but share")
    # aa("--lev_count", default=False, action="store_true", help="use counting method to compute top k over A_train?")
    return parser


if __name__ == '__main__':
    runtype = "train_regression"
    # initalg_name2fn_dict = {"kmeans": init_w_kmeans, "lev": init_w_lev, "gs": init_w_gramschmidt,
    #                         "lev_cluster": init_w_lev_cluster, "load": init_w_load}

    parser = make_parser_reg()
    args = parser.parse_known_args()[0]
    # rawdir = "/Users/siminliu/F19_classes/research/big-regression/"
    rawdir = "/Users/lynette/Desktop/algorithm/final project"
    # rltdir = "/Users/siminliu/F19_classes/research/big-regression/"
    rltdir = "/Users/lynette/Desktop/algorithm/final project"
    print(args)
    m = args.m

    if args.data == 'ghg':
        save_dir_prefix = os.path.join(rltdir, "rlt", "ghg")
        # print("---------------testing1-----------")
        # TODO
    elif args.data == 'gas':
        save_dir_prefix = os.path.join(rltdir, "rlt", "gas")
    elif args.data == 'electric':
        save_dir_prefix = os.path.join(rltdir, "rlt", "electric")
    else:
        print("Wrong data option!")
        sys.exit()

    if args.save_file:
        runtype = runtype + "_" + args.save_file
    if args.save_fldr:
        save_dir = os.path.join(
            save_dir_prefix, args.save_fldr, args_to_fldrname(runtype, args))
    else:
        save_dir = os.path.join(
            save_dir_prefix, args_to_fldrname(runtype, args))
    # print("---------------testing2-----------")
    best_fl_save_dir = os.path.join(save_dir_prefix, "best_files")
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    if not os.path.exists(best_fl_save_dir):
        os.makedirs(best_fl_save_dir)

    if (not args.bestonly) and (len(os.listdir(save_dir))):
        print("This experiment is already done! Now exiting.")
        # sys.exit()
    lr = args.lr  # default = 1
    if args.data == "ghg":
        AB_train, AB_test, n, d_a, d_b = getGHG(
            args.raw, args.size, rawdir, 100)
        A_train = AB_train[0]
        B_train = AB_train[1]
        A_test = AB_test[0]
        B_test = AB_test[1]
    elif args.data == "gas":
        AB_train, AB_test, n, d_a, d_b = getGas(args.raw, rawdir, 100)
        A_train = AB_train[0]
        B_train = AB_train[1]
        A_test = AB_test[0]
        B_test = AB_test[1]
    elif args.data == "electric":
        AB_train, AB_test, n, d_a, d_b = getElectric(args.raw, rawdir, 100)
        A_train = AB_train[0]
        B_train = AB_train[1]
        A_test = AB_test[0]
        B_test = AB_test[1]
    # TODO
    # print("ln 106 in train_regression.py: check if we fetched data correctly")
    # IPython.embed()
    # lr = lr * args.lr_S
    print("Working on data ", args.data)

    Path(save_dir).mkdir(parents=True, exist_ok=True)

    N_train = len(A_train)
    N_test = len(A_test)
    print("Dim= ", n, d_a, d_b)
    print("N train=", N_train, "N test=", N_test)
    p = 1.5
    best_file = os.path.join(best_fl_save_dir, "N=" + str(args.size) + '_best')
    # if (not os.path.isfile(best_file)) or args.raw:
    print("computing best hp regression approximations")
    getbest_hb_regression(A_train, B_train, A_test, B_test, best_file)
    best_train, best_test = torch.load(best_file)
    #print("Best: train:%f , test:%f" % (best_train, best_test))
    # to get error again
    # print("computing best lp regression loss")
    # getbest_lp_regression(A_train, B_train, A_test, B_test, best_file, p)

    # print("ln 125 in train_regression; check if best errors are properly loaded")
    # IPython.embed()
    start = time.time()
    print_freq = 50  # TODO

    # save args
    args_save_fpath = os.path.join(save_dir, "args_it_0.pkl")
    f = open(args_save_fpath, "wb")
    pickle.dump(vars(args), f)
    f.close()

    avg_over_exps = 0
    for exp_num in range(args.num_exp):

        it_save_dir = os.path.join(save_dir, "exp_%d" % exp_num)
        it_print_freq = print_freq
        it_lr = lr

        if not os.path.exists(it_save_dir):
            os.makedirs(it_save_dir)

        test_errs = []
        train_errs = []
        fp_times = []
        bp_times = []

        # Initialize sparsity pattern
        if args.initalg == "random":
            sketch_vector = torch.randint(m, [args.k_sparse, n]).int()
            sketch_vector = torch.randint(m, [args.k_sparse, n]).int()
            print()
            print("-----------doing random-----------")
        elif args.initalg == "load":
            # TODO: not implemented for ksparse
            initalg = initalg_name2fn_dict[args.initalg]
            sketch_vector, sketch_value_cpu, active_ind = initalg(
                args.load_file, exp_num, n, m)
            sketch_value = sketch_value_cpu.detach()  # .to(args.device)

        # Note: we sample with repeats, so you may map 1 row of A to <k_sparse distinct locations
        sketch_vector.requires_grad = False
        if args.initalg != "load":
            if args.S_init_method == "pm1":
                sketch_value = (
                    (torch.randint(2, [args.k_sparse, n]).float() - 0.5) * 2)  # .to(args.device)
                # print("-------pm1----sketch_value--------")
                # print(sketch_value.size)
            elif args.S_init_method == "gaussian":
                sketch_value = torch.from_numpy(np.random.normal(
                    size=[args.k_sparse, n]).astype("float32"))  # .to(args.device)
                # sketch_value_cpu = ((torch.randint(2, [args.k_sparse, n]).float() - 0.5) * 2).to(args.device)
            elif args.S_init_method == "gaussian_pm1":
                sketch_value = (
                    (torch.randint(2, [args.k_sparse, n]).float() - 0.5) * 2)  # .to(args.device)
                sketch_value = sketch_value + torch.from_numpy(
                    np.random.normal(size=[args.k_sparse, n]).astype("float32"))  # .to(args.device)

        sketch_value.requires_grad = True

        for bigstep in tqdm(range(args.iter)):
            if (bigstep % 1000 == 0) and it_lr > 1:
                it_lr = it_lr * 0.3
            if bigstep > 200:
                it_print_freq = 200

            fp_start_time = time.time()
            # to randomly choose for gd
            batch_rand_ind = np.random.randint(0, high=N_train, size=args.bs)

            AM = A_train[batch_rand_ind]  # .to(args.device)
            BM = B_train[batch_rand_ind]  # .to(args.device)

            S = torch.zeros(m, n)  # .to(args.device)
            S[sketch_vector.type(torch.LongTensor).reshape(-1), torch.arange(n).repeat(
                args.k_sparse)] = sketch_value.reshape(-1)

            if bigstep % it_print_freq == 0 or bigstep == (args.iter - 1):
                # IPython.embed()
                train_err, test_err = save_iteration_regression(
                    S, A_train, B_train, A_test, B_test, it_save_dir, bigstep, p)
                train_errs.append(train_err)
                test_errs.append(test_err)
                if bigstep == (args.iter - 1):
                    # num_exp =how many times run
                    avg_over_exps += (test_err/args.num_exp)
                if args.random:
                    # don't train! after evaluating, exit trial
                    break
            SA = torch.matmul(S, AM)
            SB = torch.matmul(S, BM)

            # print("-------------------------------------")
            # print(S.shape)
            # print(AM.shape)
            # print(SA.shape)
            # print("-------------------------------------")
            ##################-----------------------##################
            # U, Sig, V = torch.svd(SA)
            # X = V.matmul(torch.diag_embed(1.0/Sig)
            #              ).matmul(U.permute(0, 2, 1)).matmul(SB)
            ##################-----------------------##################

            ###########----lp-norm----#######
            # X = lp_norm_regression(p, SA, SB)
            ###############################
            nsamples, nx, ny = SA.shape
            A = SA.reshape((nsamples*nx, ny))
            nsamples, nx, ny = SB.shape
            # B = column_or_1d(y, warn=True)
            B = SB.reshape((nsamples*nx, ny))
            BN = B.detach().numpy()
            AN = A.detach().numpy()
            huber = HuberRegressor().fit(AN, BN.ravel())
            X = torch.from_numpy(huber.coef_)
            X = X.to(device=device, dtype=torch.float32)
            nsamples, nx, ny = AM.shape
            AMM = AM.reshape((nsamples*nx, ny))
            nsamples, nx, ny = BM.shape
            BMM = BM.reshape((nsamples*nx, ny))
            ans = AMM.matmul(X)
            loss = torch.mean(torch.norm(ans - B))
            fp_times.append(time.time() - fp_start_time)
            bp_start_time = time.time()
            loss.backward()
            bp_times.append(time.time() - bp_start_time)

            # TODO: Maybe don't have to divide by args.bs: is this similar to lev_score_experiments bug?
            # However, if you change it, then you need to compensate in lr... all old exp will be invalidated
            with torch.no_grad():
                if args.initalg == "load":
                    sketch_value[active_ind] -= (it_lr / args.bs) * \
                        sketch_value.grad[active_ind]
                    sketch_value.grad.zero_()
                else:
                    sketch_value -= (it_lr / args.bs) * sketch_value.grad
                    sketch_value.grad.zero_()

            # del SA, SB, U, Sig, V, X, ans, loss
            del SA, SB, X, ans, loss
            torch.cuda.empty_cache()

        np.save(os.path.join(it_save_dir, "train_errs.npy"),
                train_errs, allow_pickle=True)
        np.save(os.path.join(it_save_dir, "test_errs.npy"),
                test_errs, allow_pickle=True)
        np.save(os.path.join(it_save_dir, "fp_times.npy"),
                fp_times, allow_pickle=True)
        np.save(os.path.join(it_save_dir, "bp_times.npy"),
                bp_times, allow_pickle=True)
    print(avg_over_exps)
# Out:
# Running experiment on device: cpu:0
# Namespace(S_init_method='gaussian', bestonly=False, bs=10, data='ghg', device='cuda:0', initalg='random', iter=8000, k_sparse=1, load_file='', lr=0.0001, m=10, num_exp=1, random=False, raw=True, save_file=None, save_fldr=None, size=2000)
# -----------------------data process begins----------------------
# 0
# (15, 327)
# ghg.gid.site2547.dat
# 1
# (15, 327)
# ghg.gid.site2283.dat
# 2
# (15, 327)
# ghg.gid.site1250.dat
# 3
# (15, 327)
# ghg.gid.site2020.dat
# 4
# (15, 327)
# ghg.gid.site2271.dat
# 5
# (15, 327)
# ghg.gid.site1936.dat
# 6
# (15, 327)
# ghg.gid.site1942.dat
# 7
# (15, 327)
# ghg.gid.site1625.dat
# 8
# (15, 327)
# ghg.gid.site1694.dat
# 9
# (15, 327)
# ghg.gid.site2289.dat
# 10
# (15, 327)
# ghg.gid.site0511.dat
# 11
# (15, 327)
# ghg.gid.site0119.dat
# 12
# (15, 327)
# ghg.gid.site1927.dat
# 13
# (15, 327)
# ghg.gid.site0567.dat
# 14
# (15, 327)
# ghg.gid.site0483.dat
# 15
# (15, 327)
# ghg.gid.site0190.dat
# 16
# (15, 327)
# ghg.gid.site1007.dat
# 17
# (15, 327)
# ghg.gid.site2401.dat
# 18
# (15, 327)
# ghg.gid.site1564.dat
# 19
# (15, 327)
# ghg.gid.site0262.dat
# 20
# (15, 327)
# ghg.gid.site2381.dat
# 21
# (15, 327)
# ghg.gid.site2299.dat
# 22
# (15, 327)
# ghg.gid.site0787.dat
# 23
# (15, 327)
# ghg.gid.site0360.dat
# 24
# (15, 327)
# ghg.gid.site0092.dat
# 25
# (15, 327)
# ghg.gid.site0864.dat
# 26
# (15, 327)
# ghg.gid.site0694.dat
# 27
# (15, 327)
# ghg.gid.site0911.dat
# 28
# (15, 327)
# ghg.gid.site0862.dat
# 29
# (15, 327)
# ghg.gid.site2866.dat
# 30
# (15, 327)
# ghg.gid.site1569.dat
# 31
# (15, 327)
# ghg.gid.site2385.dat
# 32
# (15, 327)
# ghg.gid.site0015.dat
# 33
# (15, 327)
# ghg.gid.site2007.dat
# 34
# (15, 327)
# ghg.gid.site1193.dat
# 35
# (15, 327)
# ghg.gid.site1018.dat
# 36
# (15, 327)
# ghg.gid.site1091.dat
# 37
# (15, 327)
# ghg.gid.site0348.dat
# 38
# (15, 327)
# ghg.gid.site0995.dat
# 39
# (15, 327)
# ghg.gid.site2698.dat
# 40
# (15, 327)
# ghg.gid.site2566.dat
# 41
# (15, 327)
# ghg.gid.site1254.dat
# 42
# (15, 327)
# ghg.gid.site2858.dat
# 43
# (15, 327)
# ghg.gid.site2275.dat
# 44
# (15, 327)
# ghg.gid.site2588.dat
# 45
# (15, 327)
# ghg.gid.site1226.dat
# 46
# (15, 327)
# ghg.gid.site1543.dat
# 47
# (15, 327)
# ghg.gid.site2226.dat
# 48
# (15, 327)
# ghg.gid.site0237.dat
# 49
# (15, 327)
# ghg.gid.site1586.dat
# 50
# (15, 327)
# ghg.gid.site0687.dat
# 51
# (15, 327)
# ghg.gid.site0988.dat
# 52
# (15, 327)
# ghg.gid.site0101.dat
# 53
# (15, 327)
# ghg.gid.site0192.dat
# 54
# (15, 327)
# ghg.gid.site1453.dat
# 55
# (15, 327)
# ghg.gid.site1562.dat
# 56
# (15, 327)
# ghg.gid.site2138.dat
# 57
# (15, 327)
# ghg.gid.site1106.dat
# 58
# (15, 327)
# ghg.gid.site2571.dat
# 59
# (15, 327)
# ghg.gid.site1039.dat
# 60
# (15, 327)
# ghg.gid.site1583.dat
# 61
# (15, 327)
# ghg.gid.site1999.dat
# 62
# (15, 327)
# ghg.gid.site0771.dat
# 63
# (15, 327)
# ghg.gid.site0830.dat
# 64
# (15, 327)
# ghg.gid.site0479.dat
# 65
# (15, 327)
# ghg.gid.site2214.dat
# 66
# (15, 327)
# ghg.gid.site1078.dat
# 67
# (15, 327)
# ghg.gid.site0399.dat
# 68
# (15, 327)
# ghg.gid.site0715.dat
# 69
# (15, 327)
# ghg.gid.site0381.dat
# 70
# (15, 327)
# ghg.gid.site0157.dat
# 71
# (15, 327)
# ghg.gid.site2847.dat
# 72
# (15, 327)
# ghg.gid.site0156.dat
# 73
# (15, 327)
# ghg.gid.site1105.dat
# 74
# (15, 327)
# ghg.gid.site0607.dat
# 75
# (15, 327)
# ghg.gid.site2730.dat
# 76
# (15, 327)
# ghg.gid.site0441.dat
# 77
# (15, 327)
# ghg.gid.site0202.dat
# 78
# (15, 327)
# ghg.gid.site0328.dat
# 79
# (15, 327)
# ghg.gid.site2139.dat
# 80
# (15, 327)
# ghg.gid.site2895.dat
# 81
# (15, 327)
# ghg.gid.site2375.dat
# 82
# (15, 327)
# ghg.gid.site2431.dat
# 83
# (15, 327)
# ghg.gid.site1244.dat
# 84
# (15, 327)
# ghg.gid.site1629.dat
# 85
# ghg.gid.site0044.dat
# 1959
# (15, 327)
# ghg.gid.site1203.dat
# 1960
# (15, 327)
# ghg.gid.site0037.dat
# 1961
# (15, 327)
# ghg.gid.site1986.dat
# 1962
# (15, 327)
# ghg.gid.site2461.dat
# 1963
# (15, 327)
# ghg.gid.site0608.dat
# 1964
# (15, 327)
# ghg.gid.site0184.dat
# 1965
# (15, 327)
# ghg.gid.site2575.dat
# 1966
# (15, 327)
# ghg.gid.site2425.dat
# 1967
# (15, 327)
# ghg.gid.site1674.dat
# 1968
# (15, 327)
# ghg.gid.site2880.dat
# 1969
# (15, 327)
# ghg.gid.site1111.dat
# 1970
# (15, 327)
# ghg.gid.site1535.dat
# 1971
# (15, 327)
# ghg.gid.site2129.dat
# 1972
# (15, 327)
# ghg.gid.site0562.dat
# 1973
# (15, 327)
# ghg.gid.site2863.dat
# 1974
# (15, 327)
# ghg.gid.site0387.dat
# 1975
# (15, 327)
# ghg.gid.site0902.dat
# 1976
# (15, 327)
# ghg.gid.site1123.dat
# 1977
# (15, 327)
# ghg.gid.site0334.dat
# 1978
# (15, 327)
# ghg.gid.site1472.dat
# 1979
# (15, 327)
# ghg.gid.site0445.dat
# 1980
# (15, 327)
# ghg.gid.site0446.dat
# 1981
# (15, 327)
# ghg.gid.site0970.dat
# 1982
# (15, 327)
# ghg.gid.site0964.dat
# 1983
# (15, 327)
# ghg.gid.site0094.dat
# 1984
# (15, 327)
# ghg.gid.site0745.dat
# 1985
# (15, 327)
# ghg.gid.site0046.dat
# 1986
# (15, 327)
# ghg.gid.site0489.dat
# 1987
# (15, 327)
# ghg.gid.site2204.dat
# 1988
# (15, 327)
# ghg.gid.site2308.dat
# 1989
# (15, 327)
# ghg.gid.site0214.dat
# 1990
# (15, 327)
# ghg.gid.site1293.dat
# 1991
# (15, 327)
# ghg.gid.site0142.dat
# 1992
# (15, 327)
# ghg.gid.site2186.dat
# 1993
# (15, 327)
# ghg.gid.site1251.dat
# 1994
# (15, 327)
# ghg.gid.site2915.dat
# 1995
# (15, 327)
# ghg.gid.site1263.dat
# 1996
# (15, 327)
# ghg.gid.site2124.dat
# 1997
# (15, 327)
# ghg.gid.site1777.dat
# 1998
# (15, 327)
# ghg.gid.site0506.dat
# 1999
# (15, 327)
# ghg.gid.site1102.dat
# ----------------data process finish-----------------
# Working on data  ghg
# Dim=  327 14 1
# N train= 1600 N test= 400
# computing best hp regression approximations
# ======================Huber regression===============
# 724.526798248291
# 0.45185934099628716
# ======================Huber regression===============
#   0%|          | 0/8000 [00:00<?, ?it/s]
# ======================Huber regression===============
# 740.4303283691406
# 0.4598897168008734
# ======================Huber regression===============
#
# -----------doing random-----------
# -------finish evaluating-------
#   0%|          | 1/8000 [11:26<1526:19:36, 686.93s/it]
# -------finish evaluating-------
# 776.7083129882812 799.9585876464844
# Saved iteration: 0
#   1%|          | 50/8000 [11:40<10:21:17,  4.69s/it]
# -------finish evaluating-------
#   1%|          | 51/8000 [23:27<483:24:12, 218.93s/it]
# -------finish evaluating-------
# 744.3716201782227 769.1760711669922
# Saved iteration: 50
#   1%|          | 99/8000 [23:41<3:19:23,  1.51s/it]
# -------finish evaluating-------
#   1%|▏         | 101/8000 [35:02<230:29:49, 105.05s/it]
# -------finish evaluating-------
# 727.2013359069824 749.1943206787109
# Saved iteration: 100
#   2%|▏         | 149/8000 [35:22<1:37:04,  1.35it/s]
# -------finish evaluating-------
#   2%|▏         | 151/8000 [46:28<225:04:50, 103.23s/it]
# -------finish evaluating-------
# 723.9999885559082 741.5288848876953
# Saved iteration: 150
#   2%|▏         | 197/8000 [46:42<2:13:57,  1.03s/it]
# -------finish evaluating-------
#   3%|▎         | 201/8000 [58:11<115:32:53, 53.34s/it]
# -------finish evaluating-------
# 723.4070739746094 740.1922607421875
# Saved iteration: 200
#   5%|▌         | 400/8000 [58:33<03:44, 33.90it/s]
# -------finish evaluating-------
#   5%|▌         | 401/8000 [1:10:14<453:43:24, 214.95s/it]
# -------finish evaluating-------
# 723.1414108276367 739.8416442871094
# Saved iteration: 400
#   7%|▋         | 597/8000 [1:10:34<03:32, 34.83it/s]
# -------finish evaluating-------
#   8%|▊         | 601/8000 [1:24:55<134:56:35, 65.66s/it]
# -------finish evaluating-------
# 723.1632270812988 740.4097290039062
# Saved iteration: 600
#  10%|█         | 800/8000 [1:25:15<04:07, 29.13it/s]
# -------finish evaluating-------
#  10%|█         | 801/8000 [1:39:49<531:32:52, 265.81s/it]
# -------finish evaluating-------
# 723.0339736938477 740.4070434570312
# Saved iteration: 800
#  12%|█▏        | 999/8000 [1:40:05<04:45, 24.53it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# 723.0133743286133 740.7602691650391
# Saved iteration: 1000
#  15%|█▍        | 1198/8000 [1:52:50<03:41, 30.73it/s]
# -------finish evaluating-------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-633e889a9ef2> in <module>
#     238                 # IPython.embed()
#     239                 train_err, test_err = save_iteration_regression(
# --> 240                     S, A_train, B_train, A_test, B_test, it_save_dir, bigstep, p)
#     241                 train_errs.append(train_err)
#     242                 test_errs.append(test_err)
#
# ~/Desktop/algorithm/final project/WEEK TWO/learned_HB_regression_code/misc_utils.py in save_iteration_regression(S, A_train, B_train, A_test, B_test, save_dir, bigstep, p)
#      48     test_err = evaluate_to_rule_them_all_huber_regression(A_test, B_test, S)
#      49     train_err = evaluate_to_rule_them_all_huber_regression(
# ---> 50         A_train, B_train, S)
#      51     torch.save([[S], [train_err, test_err]], torch_save_fpath)
#      52
#
# ~/Desktop/algorithm/final project/WEEK TWO/learned_HB_regression_code/evaluate.py in evaluate_to_rule_them_all_huber_regression(A_set, B_set, S)
#      45         BMM = BM.reshape((nsamples*nx, ny))
#      46         ans = AMM.matmul(X)
# ---> 47         it_loss = torch.sum(torch.norm(ans - BMM))/n
#      48         loss += it_loss.item()
#      49     # print("in evaluate.py, ln 154")
#
# KeyboardInterrupt:

# %%
# %load train_regression
import argparse
import os
import torch
from data.ghg import getGHG
from data.gas import getGas
from data.electric import getElectric
from evaluate import *
from pathlib import Path
import sys
import time
from misc_utils import *
import warnings
from tqdm import tqdm
import numpy as np
from sklearn.datasets import make_regression
from sklearn.linear_model import HuberRegressor, LinearRegression


def make_parser_reg():
    parser = argparse.ArgumentParser()

    def aa(*args, **kwargs):
        parser.add_argument(*args, **kwargs)

    aa("--data", type=str, default="ghg", help="ghg|gas|electric")
   # aa("--dataname", type=str, default="mit", help="eagle|mit|friends")
    aa("--m", type=int, default=10, help="m for S")
    # the row num of S
    # aa("--k", type=int, default=10, help="target: rank k approximation")
    # aa("--mp", type=int, default=10, help="mp for R")
    aa("--iter", type=int, default=3000, help="total iterations")
    # aa("--scale", type=int, default= 100, help="scale") # not a functioning argument, assume 100

    aa("--random", default=False, action='store_true',
       help="don't learn S! Just compute error on random S")

    aa("--size", type=int, default=2000, help="dataset size")
    # aa("--bw", dest='bw', default=False, action='store_true', help="input images to black and white")
    # aa("--dwnsmp", type=int, default=1, help="how much to downsample input images")
    # aa("--dense", type=int, default=-1, help="calculate dense?")
    # aa("--lr_S", type=float, default=1.0, help="learning rate scale?")
    aa("--lr", type=float, default=1e-4, help="learning rate for gradient descent")
    aa("--raw", dest='raw', default=True,
       action='store_true', help="generate raw?")
    aa("--bestonly", dest='bestonly', default=False,
       action='store_true', help="only compute best?")
    aa("--device", type=str, default="cuda:0")

    # aa("--n_sample_rows", type=int, default=-1, help="Train with n_sample_rows rows")
    aa("--k_sparse", type=int, default=1,
       help="number of values in a column of S, sketching mat")
    aa("--num_exp", type=int, default=1,
       help="number of times to rerun the experiment (for avg'ing results)")
    aa("--bs", type=int, default=10, help="batch size")
    aa("--initalg", type=str, default="random",
       help="random|kmeans|lev|gs|lev_cluster|load")
    aa("--load_file", type=str, default="",
       help="if initalg=load, where to get S?")

    aa("--save_fldr", type=str,
       help="folder to save experiment results into; if None, then general folder")  # default: None
    aa("--save_file", type=str, help="append to runtype, if not None")

    aa("--S_init_method", type=str, default="gaussian",
       help="pm1|gaussian|gaussian_pm1")
    # aa("--lev_ridge", dest='lev_ridge', default=False, action='store_true',
    #    help="use ridge regression version with lambda?")
    # aa("--lev_cutoff", type=int, help="how many top k to isolate; must be <=m? if m, then not isolate, but share")
    # aa("--lev_count", default=False, action="store_true", help="use counting method to compute top k over A_train?")
    return parser


if __name__ == '__main__':
    runtype = "train_regression"
    # initalg_name2fn_dict = {"kmeans": init_w_kmeans, "lev": init_w_lev, "gs": init_w_gramschmidt,
    #                         "lev_cluster": init_w_lev_cluster, "load": init_w_load}

    parser = make_parser_reg()
    args = parser.parse_known_args()[0]
    # rawdir = "/Users/siminliu/F19_classes/research/big-regression/"
    rawdir = "/Users/lynette/Desktop/algorithm/final project"
    # rltdir = "/Users/siminliu/F19_classes/research/big-regression/"
    rltdir = "/Users/lynette/Desktop/algorithm/final project"
    print(args)
    m = args.m

    if args.data == 'ghg':
        save_dir_prefix = os.path.join(rltdir, "rlt", "ghg")
        # print("---------------testing1-----------")
        # TODO
    elif args.data == 'gas':
        save_dir_prefix = os.path.join(rltdir, "rlt", "gas")
    elif args.data == 'electric':
        save_dir_prefix = os.path.join(rltdir, "rlt", "electric")
    else:
        print("Wrong data option!")
        sys.exit()

    if args.save_file:
        runtype = runtype + "_" + args.save_file
    if args.save_fldr:
        save_dir = os.path.join(
            save_dir_prefix, args.save_fldr, args_to_fldrname(runtype, args))
    else:
        save_dir = os.path.join(
            save_dir_prefix, args_to_fldrname(runtype, args))
    # print("---------------testing2-----------")
    best_fl_save_dir = os.path.join(save_dir_prefix, "best_files")
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    if not os.path.exists(best_fl_save_dir):
        os.makedirs(best_fl_save_dir)

    if (not args.bestonly) and (len(os.listdir(save_dir))):
        print("This experiment is already done! Now exiting.")
        # sys.exit()
    lr = args.lr  # default = 1
    if args.data == "ghg":
        AB_train, AB_test, n, d_a, d_b = getGHG(
            args.raw, args.size, rawdir, 100)
        A_train = AB_train[0]
        B_train = AB_train[1]
        A_test = AB_test[0]
        B_test = AB_test[1]
    elif args.data == "gas":
        AB_train, AB_test, n, d_a, d_b = getGas(args.raw, rawdir, 100)
        A_train = AB_train[0]
        B_train = AB_train[1]
        A_test = AB_test[0]
        B_test = AB_test[1]
    elif args.data == "electric":
        AB_train, AB_test, n, d_a, d_b = getElectric(args.raw, rawdir, 100)
        A_train = AB_train[0]
        B_train = AB_train[1]
        A_test = AB_test[0]
        B_test = AB_test[1]
    # TODO
    # print("ln 106 in train_regression.py: check if we fetched data correctly")
    # IPython.embed()
    # lr = lr * args.lr_S
    print("Working on data ", args.data)

    Path(save_dir).mkdir(parents=True, exist_ok=True)

    N_train = len(A_train)
    N_test = len(A_test)
    print("Dim= ", n, d_a, d_b)
    print("N train=", N_train, "N test=", N_test)
    p = 1.5
    best_file = os.path.join(best_fl_save_dir, "N=" + str(args.size) + '_best')
    # if (not os.path.isfile(best_file)) or args.raw:
    print("computing best hp regression approximations")
    getbest_hb_regression(A_train, B_train, A_test, B_test, best_file)
    best_train, best_test = torch.load(best_file)
    #print("Best: train:%f , test:%f" % (best_train, best_test))
    # to get error again
    # print("computing best lp regression loss")
    # getbest_lp_regression(A_train, B_train, A_test, B_test, best_file, p)

    # print("ln 125 in train_regression; check if best errors are properly loaded")
    # IPython.embed()
    start = time.time()
    print_freq = 50  # TODO

    # save args
    args_save_fpath = os.path.join(save_dir, "args_it_0.pkl")
    f = open(args_save_fpath, "wb")
    pickle.dump(vars(args), f)
    f.close()

    avg_over_exps = 0
    for exp_num in range(args.num_exp):

        it_save_dir = os.path.join(save_dir, "exp_%d" % exp_num)
        it_print_freq = print_freq
        it_lr = lr

        if not os.path.exists(it_save_dir):
            os.makedirs(it_save_dir)

        test_errs = []
        train_errs = []
        fp_times = []
        bp_times = []

        # Initialize sparsity pattern
        if args.initalg == "random":
            sketch_vector = torch.randint(m, [args.k_sparse, n]).int()
            sketch_vector = torch.randint(m, [args.k_sparse, n]).int()
            print()
            print("-----------doing random-----------")
        elif args.initalg == "load":
            # TODO: not implemented for ksparse
            initalg = initalg_name2fn_dict[args.initalg]
            sketch_vector, sketch_value_cpu, active_ind = initalg(
                args.load_file, exp_num, n, m)
            sketch_value = sketch_value_cpu.detach()  # .to(args.device)

        # Note: we sample with repeats, so you may map 1 row of A to <k_sparse distinct locations
        sketch_vector.requires_grad = False
        if args.initalg != "load":
            if args.S_init_method == "pm1":
                sketch_value = (
                    (torch.randint(2, [args.k_sparse, n]).float() - 0.5) * 2)  # .to(args.device)
                # print("-------pm1----sketch_value--------")
                # print(sketch_value.size)
            elif args.S_init_method == "gaussian":
                sketch_value = torch.from_numpy(np.random.normal(
                    size=[args.k_sparse, n]).astype("float32"))  # .to(args.device)
                # sketch_value_cpu = ((torch.randint(2, [args.k_sparse, n]).float() - 0.5) * 2).to(args.device)
            elif args.S_init_method == "gaussian_pm1":
                sketch_value = (
                    (torch.randint(2, [args.k_sparse, n]).float() - 0.5) * 2)  # .to(args.device)
                sketch_value = sketch_value + torch.from_numpy(
                    np.random.normal(size=[args.k_sparse, n]).astype("float32"))  # .to(args.device)

        sketch_value.requires_grad = True

        for bigstep in tqdm(range(args.iter)):
            if (bigstep % 1000 == 0) and it_lr > 1:
                it_lr = it_lr * 0.3
            if bigstep > 200:
                it_print_freq = 200

            fp_start_time = time.time()
            # to randomly choose for gd
            batch_rand_ind = np.random.randint(0, high=N_train, size=args.bs)

            AM = A_train[batch_rand_ind]  # .to(args.device)
            BM = B_train[batch_rand_ind]  # .to(args.device)

            S = torch.zeros(m, n)  # .to(args.device)
            S[sketch_vector.type(torch.LongTensor).reshape(-1), torch.arange(n).repeat(
                args.k_sparse)] = sketch_value.reshape(-1)

            if bigstep % it_print_freq == 0 or bigstep == (args.iter - 1):
                # IPython.embed()
                train_err, test_err = save_iteration_regression(
                    S, A_train, B_train, A_test, B_test, it_save_dir, bigstep, p)
                train_errs.append(train_err)
                test_errs.append(test_err)
                if bigstep == (args.iter - 1):
                    # num_exp =how many times run
                    avg_over_exps += (test_err/args.num_exp)
                if args.random:
                    # don't train! after evaluating, exit trial
                    break
            SA = torch.matmul(S, AM)
            SB = torch.matmul(S, BM)

            # print("-------------------------------------")
            # print(S.shape)
            # print(AM.shape)
            # print(SA.shape)
            # print("-------------------------------------")
            ##################-----------------------##################
            # U, Sig, V = torch.svd(SA)
            # X = V.matmul(torch.diag_embed(1.0/Sig)
            #              ).matmul(U.permute(0, 2, 1)).matmul(SB)
            ##################-----------------------##################

            ###########----lp-norm----#######
            # X = lp_norm_regression(p, SA, SB)
            ###############################
            nsamples, nx, ny = SA.shape
            A = SA.reshape((nsamples*nx, ny))
            nsamples, nx, ny = SB.shape
            # B = column_or_1d(y, warn=True)
            B = SB.reshape((nsamples*nx, ny))
            BN = B.detach().numpy()
            AN = A.detach().numpy()
            huber = HuberRegressor().fit(AN, BN.ravel())
            X = torch.from_numpy(huber.coef_)
            X = X.to(device=device, dtype=torch.float32)
            nsamples, nx, ny = AM.shape
            AMM = AM.reshape((nsamples*nx, ny))
            nsamples, nx, ny = BM.shape
            BMM = BM.reshape((nsamples*nx, ny))
            ans = AMM.matmul(X)
            loss = torch.sum(abs(ans - B))
            tot = evaluate_to_rule_them_all_huber_regression(AM, BM, S)
            if(bigstep == 0):
                print("----------random S----------")
                print(tot)
                print("------------random S---------")
            fp_times.append(time.time() - fp_start_time)
            bp_start_time = time.time()
            loss.backward()
            bp_times.append(time.time() - bp_start_time)
            # TODO: Maybe don't have to divide by args.bs: is this similar to lev_score_experiments bug?
            # However, if you change it, then you need to compensate in lr... all old exp will be invalidated
            with torch.no_grad():
                if args.initalg == "load":
                    sketch_value[active_ind] -= (it_lr / args.bs) * \
                        sketch_value.grad[active_ind]
                    sketch_value.grad.zero_()
                else:
                    sketch_value -= (it_lr / args.bs) * sketch_value.grad
                    sketch_value.grad.zero_()

            # del SA, SB, U, Sig, V, X, ans, loss
            del SA, SB, X, ans, loss
            torch.cuda.empty_cache()

        np.save(os.path.join(it_save_dir, "train_errs.npy"),
                train_errs, allow_pickle=True)
        np.save(os.path.join(it_save_dir, "test_errs.npy"),
                test_errs, allow_pickle=True)
        np.save(os.path.join(it_save_dir, "fp_times.npy"),
                fp_times, allow_pickle=True)
        np.save(os.path.join(it_save_dir, "bp_times.npy"),
                bp_times, allow_pickle=True)
    print(avg_over_exps)
# Out:
# Running experiment on device: cpu:0
# Namespace(S_init_method='gaussian', bestonly=False, bs=10, data='ghg', device='cuda:0', initalg='random', iter=3000, k_sparse=1, load_file='', lr=0.0001, m=10, num_exp=1, random=False, raw=True, save_file=None, save_fldr=None, size=2000)
# -----------------------data process begins----------------------
# 0
# (15, 327)
# ghg.gid.site2547.dat
# 1
# (15, 327)
# ghg.gid.site2283.dat
# 2
# (15, 327)
# ghg.gid.site1250.dat
# 3
# (15, 327)
# ghg.gid.site2020.dat
# 4
# (15, 327)
# ghg.gid.site2271.dat
# 5
# (15, 327)
# ghg.gid.site1936.dat
# 6
# (15, 327)
# ghg.gid.site1942.dat
# 7
# (15, 327)
# ghg.gid.site1625.dat
# 8
# (15, 327)
# ghg.gid.site1694.dat
# 9
# (15, 327)
# ghg.gid.site2289.dat
# 10
# (15, 327)
# ghg.gid.site0511.dat
# 11
# (15, 327)
# ghg.gid.site0119.dat
# 12
# (15, 327)
# ghg.gid.site1927.dat
# 13
# (15, 327)
# ghg.gid.site0567.dat
# 14
# (15, 327)
# ghg.gid.site0483.dat
# 15
# (15, 327)
# ghg.gid.site0190.dat
# 16
# (15, 327)
# ghg.gid.site1007.dat
# 17
# (15, 327)
# ghg.gid.site2401.dat
# 18
# (15, 327)
# ghg.gid.site1564.dat
# 19
# (15, 327)
# ghg.gid.site0262.dat
# 20
# (15, 327)
# ghg.gid.site2381.dat
# 21
# (15, 327)
# ghg.gid.site2299.dat
# 22
# (15, 327)
# ghg.gid.site0787.dat
# 23
# (15, 327)
# ghg.gid.site0360.dat
# 24
# (15, 327)
# ghg.gid.site0092.dat
# 25
# (15, 327)
# ghg.gid.site0864.dat
# 26
# (15, 327)
# ghg.gid.site0694.dat
# 27
# (15, 327)
# ghg.gid.site0911.dat
# 28
# (15, 327)
# ghg.gid.site0862.dat
# 29
# (15, 327)
# ghg.gid.site2866.dat
# 30
# (15, 327)
/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  91%|█████████▏| 2742/3000 [02:13<00:09, 28.07it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  92%|█████████▏| 2748/3000 [02:13<00:09, 27.84it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  92%|█████████▏| 2754/3000 [02:14<00:08, 27.84it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  92%|█████████▏| 2760/3000 [02:14<00:08, 28.20it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  92%|█████████▏| 2766/3000 [02:14<00:08, 28.27it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  92%|█████████▎| 2775/3000 [02:14<00:07, 28.24it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  93%|█████████▎| 2781/3000 [02:15<00:07, 28.31it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  93%|█████████▎| 2787/3000 [02:15<00:07, 28.12it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  93%|█████████▎| 2793/3000 [02:15<00:07, 27.79it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  93%|█████████▎| 2799/3000 [02:15<00:07, 28.16it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  94%|█████████▎| 2805/3000 [02:17<00:31,  6.24it/s]
# -------finish evaluating-------
# 30551581.375 30567140.5
# Saved iteration: 2800
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  94%|█████████▎| 2811/3000 [02:17<00:18, 10.23it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  94%|█████████▍| 2817/3000 [02:18<00:12, 15.05it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  94%|█████████▍| 2823/3000 [02:18<00:09, 19.43it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  94%|█████████▍| 2829/3000 [02:18<00:07, 23.03it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  94%|█████████▍| 2835/3000 [02:18<00:06, 25.01it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  95%|█████████▍| 2841/3000 [02:19<00:06, 26.15it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  95%|█████████▍| 2847/3000 [02:19<00:05, 27.16it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  95%|█████████▌| 2853/3000 [02:19<00:05, 27.33it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  95%|█████████▌| 2859/3000 [02:19<00:05, 27.74it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  96%|█████████▌| 2865/3000 [02:19<00:04, 27.79it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  96%|█████████▌| 2871/3000 [02:20<00:04, 28.13it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  96%|█████████▌| 2877/3000 [02:20<00:04, 27.96it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  96%|█████████▌| 2883/3000 [02:20<00:04, 27.29it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  96%|█████████▋| 2889/3000 [02:20<00:04, 27.18it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  96%|█████████▋| 2895/3000 [02:20<00:03, 27.24it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  97%|█████████▋| 2901/3000 [02:21<00:03, 27.68it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  97%|█████████▋| 2907/3000 [02:21<00:03, 28.02it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  97%|█████████▋| 2913/3000 [02:21<00:03, 27.99it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  97%|█████████▋| 2919/3000 [02:21<00:02, 27.74it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  98%|█████████▊| 2925/3000 [02:22<00:02, 27.58it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  98%|█████████▊| 2931/3000 [02:22<00:02, 27.78it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  98%|█████████▊| 2937/3000 [02:22<00:02, 27.76it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  98%|█████████▊| 2943/3000 [02:22<00:02, 27.68it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  98%|█████████▊| 2949/3000 [02:22<00:01, 27.77it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  98%|█████████▊| 2955/3000 [02:23<00:01, 27.65it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  99%|█████████▊| 2961/3000 [02:23<00:01, 27.63it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  99%|█████████▉| 2967/3000 [02:23<00:01, 27.65it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  99%|█████████▉| 2973/3000 [02:23<00:00, 27.62it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
#  99%|█████████▉| 2979/3000 [02:24<00:00, 27.93it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# 100%|█████████▉| 2985/3000 [02:24<00:00, 28.04it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# 100%|█████████▉| 2991/3000 [02:24<00:00, 28.11it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# 100%|█████████▉| 2997/3000 [02:24<00:00, 28.02it/s]
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# -------finish evaluating-------
# 100%|██████████| 3000/3000 [02:26<00:00, 20.47it/s]
# -------finish evaluating-------
# 30417995.125 30928129.0
# Saved iteration: 2999
# -------finish evaluating-------
# 30928129.0
